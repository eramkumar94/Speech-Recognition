# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.chdir('drive/My Drive/Colab Notebooks/Voice Recognition/')

# %%
ls
# Out:
# 'Audio (1).ipynb'  'Feature Extraction.ipynb'   Others/
#  Audio.ipynb        Files/                      svc_classifier.pkl
#  Baagunnaava/      'Model Building.ipynb'       swagatham/
#  data.csv           Namskaram/                  Testing.ipynb

# %%
import pickle

# %%
pkl_filename = "svc_classifier.pkl"
with open(pkl_filename, 'rb') as file:
  svc_model = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# <ipython-input-25-65179940e67a> in <module>()
#       1 pkl_filename = "svc_classifier.pkl"
#       2 with open(pkl_filename, 'rb') as file:
# ----> 3   svc_model = pickle.load(file)
#
# EOFError: Ran out of input
